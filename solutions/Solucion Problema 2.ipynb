# %%
# %load_ext autoreload
# %autoreload 2

# %%
from numpy import genfromtxt
from solucion_2 import train_and_plot

# %%
student_admission = genfromtxt('./student_admission.txt', delimiter=',')
X = student_admission[:,0:2]
y = student_admission[:,2]
 
train_and_plot(X, y, margin=5)

# %%
student_admission = genfromtxt('./chip_tests.txt', delimiter=',')
X = student_admission[:,0:2]
y = student_admission[:,2]
 
train_and_plot(X, y, h=0.05, margin=0.25)
